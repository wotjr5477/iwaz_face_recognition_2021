# %%
import os
import cv2

os.getcwd()
capture = cv2.VideoCapture(0)
frame = capture.read()
cv2.imshow("output",capture)
if cv2.waitKey(1000) == ord('q'):  # 키보드의 q 를 누르면 무한루프가 멈춤
    break

    capture.release()                   # 캡처 객체를 없애줌
    cv2.destroyAllWindows()             # 모든 영상 창을 닫아줌
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f5554fa1b0ad> in <module>
#       5 capture = cv2.VideoCapture(0)
#       6 frame = capture.read()
# ----> 7 cv2.imshow("output",capture)
#       8 if cv2.waitKey(1000) == ord('q'):  # 키보드의 q 를 누르면 무한루프가 멈춤
#       9     break
#
# TypeError: Expected Ptr<cv::UMat> for argument '%s'

# %%
import cv2
import time
import numpy as np
import os

capture = cv2.VideoCapture(0)
capture.set(3, 640)
capture.set(4, 480)
img_counter = 0
frame_set = []
start_time = time.time()
start_time_int = int(time.time())
path = 'C:/Users/CPB06GameN/Python/face_recognition/frame'  # 특정 폴더에 저장
count: int = 0
flag=1

for i in range(3):
    img_counter = 0            
    frame_set = []
    start_time = time.time()
    start_time_int = int(time.time())
    flag=1
    while flag==1:
        ret, frame = capture.read()
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        cv2.imshow('frame', gray)
        # 시작 2초 뒤 종료
        if int(time.time()) > start_time_int + 2:
            flag=0

        if time.time() - start_time >= 1:    
            img_name = "webcam_{}.jpg".format(img_counter)
            cv2.imwrite(os.path.expanduser(os.path.join(path, img_name)), frame)
            print("{} written!".format(img_counter))
        img_counter += 1
    print("loop")
        

        
capture.release()
cv.destroyAllWindows()
# Out:
# 24 written!
# 25 written!
# 26 written!
# 27 written!
# 28 written!
# 29 written!
# 30 written!
# 31 written!
# 32 written!
# 33 written!
# 34 written!
# 35 written!
# 36 written!
# 37 written!
# 38 written!
# 39 written!
# 40 written!
# 41 written!
# 42 written!
# 43 written!
# 44 written!
# 45 written!
# 46 written!
# 47 written!
# 48 written!
# 49 written!
# 50 written!
# 51 written!
# 52 written!
# 53 written!
# 54 written!
# 55 written!
# 56 written!
# 57 written!
# 58 written!
# 59 written!
# 60 written!
# 61 written!
# 62 written!
# 63 written!
# 64 written!
# 65 written!
# 66 written!
# 67 written!
# 68 written!
# 69 written!
# 70 written!
# 71 written!
# 72 written!
# 73 written!
# 74 written!
# 75 written!
# 76 written!
# loop
# 30 written!
# 31 written!
# 32 written!
# 33 written!
# 34 written!
# 35 written!
# 36 written!
# 37 written!
# 38 written!
# 39 written!
# 40 written!
# 41 written!
# 42 written!
# 43 written!
# 44 written!
# 45 written!
# 46 written!
# 47 written!
# 48 written!
# 49 written!
# 50 written!
# 51 written!
# 52 written!
# 53 written!
# 54 written!
# 55 written!
# 56 written!
# 57 written!
# 58 written!
# 59 written!
# 60 written!
# 61 written!
# 62 written!
# 63 written!
# 64 written!
# 65 written!
# 66 written!
# 67 written!
# 68 written!
# 69 written!
# 70 written!
# 71 written!
# 72 written!
# 73 written!
# 74 written!
# 75 written!
# 76 written!
# 77 written!
# 78 written!
# 79 written!
# 80 written!
# 81 written!
# 82 written!
# 83 written!
# 84 written!
# 85 written!
# 86 written!
# 87 written!
# 88 written!
# 89 written!
# loop
# 29 written!
# 30 written!
# 31 written!
# 32 written!
# 33 written!
# 34 written!
# 35 written!
# 36 written!
# 37 written!
# 38 written!
# 39 written!
# 40 written!
# 41 written!
# 42 written!
# 43 written!
# 44 written!
# 45 written!
# 46 written!
# 47 written!
# 48 written!
# 49 written!
# 50 written!
# 51 written!
# 52 written!
# 53 written!
# 54 written!
# 55 written!
# 56 written!
# 57 written!
# 58 written!
# 59 written!
# 60 written!
# 61 written!
# 62 written!
# 63 written!
# 64 written!
# 65 written!
# 66 written!
# 67 written!
# 68 written!
# 69 written!
# 70 written!
# 71 written!
# 72 written!
# 73 written!
# 74 written!
# 75 written!
# 76 written!
# 77 written!
# 78 written!
# 79 written!
# 80 written!
# 81 written!
# 82 written!
# 83 written!
# 84 written!
# 85 written!
# 86 written!
# 87 written!
# 88 written!
# loop
